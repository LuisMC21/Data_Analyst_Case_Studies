# %% [markdown]
# # Data Analysis & Data Presentation (Movies Dataset)

# %% [markdown]
# ## Data Import and first Inspection

# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
pd.options.display.max_columns = 12
pd.options.display.float_format = '{:.2f}'.format

# %%
df1 = pd.read_csv("movies_complete1.csv", parse_dates= ["release_date"])
df2 = pd.read_csv("movies_complete2.csv", parse_dates= ["release_date"])

df = pd.concat([df1,df2])
df
# Out:
#            id                        title  \
# 0         862                    Toy Story
# 1        8844                      Jumanji
# 2       15602             Grumpier Old Men
# 3       31357            Waiting to Exhale
# 4       11862  Father of the Bride Part II
# ...       ...                          ...
# 22341  439050                       Subdue
# 22342  111109          Century of Birthing
# 22343   67758                     Betrayal
# 22344  227506             Satan Triumphant
# 22345  461257                     Queerama
#
#                                                  tagline release_date  \
# 0                                                    NaN   1995-10-30
# 1              Roll the dice and unleash the excitement!   1995-12-15
# 2      Still Yelling. Still Fighting. Still Ready for...   1995-12-22
# 3      Friends are the people who let you be yourself...   1995-12-22
# 4      Just When His World Is Back To Normal... He's ...   1995-02-10
# ...                                                  ...          ...
# 22341         Rising and falling between a man and woman          NaT
# 22342                                                NaN   2011-11-17
# 22343                             A deadly game of wits.   2003-08-01
# 22344                                                NaN   1917-10-21
# 22345                                                NaN   2017-06-09
#
#                          genres           belongs_to_collection  ...  \
# 0       Animation|Comedy|Family            Toy Story Collection  ...
# 1      Adventure|Fantasy|Family                             NaN  ...
# 2                Romance|Comedy       Grumpy Old Men Collection  ...
# 3          Comedy|Drama|Romance                             NaN  ...
# 4                        Comedy  Father of the Bride Collection  ...
# ...                         ...                             ...  ...
# 22341              Drama|Family                             NaN  ...
# 22342                     Drama                             NaN  ...
# 22343     Action|Drama|Thriller                             NaN  ...
# 22344                       NaN                             NaN  ...
# 22345                       NaN                             NaN  ...
#
#        spoken_languages                                        poster_path  \
# 0               English  <img src='http://image.tmdb.org/t/p/w185//uXDf...
# 1      English|Français  <img src='http://image.tmdb.org/t/p/w185//vgpX...
# 2               English  <img src='http://image.tmdb.org/t/p/w185//1FSX...
# 3               English  <img src='http://image.tmdb.org/t/p/w185//4wjG...
# 4               English  <img src='http://image.tmdb.org/t/p/w185//lf9R...
# ...                 ...                                                ...
# 22341             فارسی  <img src='http://image.tmdb.org/t/p/w185//pfC8...
# 22342               NaN  <img src='http://image.tmdb.org/t/p/w185//xZkm...
# 22343           English  <img src='http://image.tmdb.org/t/p/w185//eGga...
# 22344               NaN  <img src='http://image.tmdb.org/t/p/w185//aorB...
# 22345           English  <img src='http://image.tmdb.org/t/p/w185//oxFE...
#
#                                                     cast cast_size crew_size  \
# 0      Tom Hanks|Tim Allen|Don Rickles|Jim Varney|Wal...        13       106
# 1      Robin Williams|Jonathan Hyde|Kirsten Dunst|Bra...        26        16
# 2      Walter Matthau|Jack Lemmon|Ann-Margret|Sophia ...         7         4
# 3      Whitney Houston|Angela Bassett|Loretta Devine|...        10        10
# 4      Steve Martin|Diane Keaton|Martin Short|Kimberl...        12         7
# ...                                                  ...       ...       ...
# 22341            Leila Hatami|Kourosh Tahami|Elham Korda         3         9
# 22342  Angel Aquino|Perry Dizon|Hazel Orencio|Joel To...        11         6
# 22343  Erika Eleniak|Adam Baldwin|Julie du Page|James...        15         5
# 22344  Iwan Mosschuchin|Nathalie Lissenko|Pavel Pavlo...         5         2
# 22345                                                NaN         0         1
#
#                director
# 0         John Lasseter
# 1          Joe Johnston
# 2         Howard Deutch
# 3       Forest Whitaker
# 4         Charles Shyer
# ...                 ...
# 22341  Hamid Nematollah
# 22342          Lav Diaz
# 22343    Mark L. Lester
# 22344  Yakov Protazanov
# 22345     Daisy Asquith
#
# [44691 rows x 22 columns]

# %%
df.dtypes
# Out:
# id                                int64
# title                            object
# tagline                          object
# release_date             datetime64[ns]
# genres                           object
# belongs_to_collection            object
# original_language                object
# budget_musd                     float64
# revenue_musd                    float64
# production_companies             object
# production_countries             object
# vote_count                      float64
# vote_average                    float64
# popularity                      float64
# runtime                         float64
# overview                         object
# spoken_languages                 object
# poster_path                      object
# cast                             object
# cast_size                         int64
# crew_size                         int64
# director                         object
# dtype: object

# %%
df.isna().sum()
# Out:
# id                           0
# title                        0
# tagline                  24407
# release_date                34
# genres                    2105
# belongs_to_collection    40228
# original_language           10
# budget_musd              35837
# revenue_musd             37306
# production_companies     11335
# production_countries      5856
# vote_count                   0
# vote_average              2614
# popularity                   0
# runtime                   1512
# overview                   951
# spoken_languages          3597
# poster_path                224
# cast                      2189
# cast_size                    0
# crew_size                    0
# director                   731
# dtype: int64

# %% [markdown]
# __Features__:

# %% [markdown]
# * **id:** The ID of the movie (clear/unique identifier).
# * **title:** The Official Title of the movie.
# * **tagline:** The tagline of the movie.
# * **release_date:** Theatrical Release Date of the movie.
# * **genres:** Genres associated with the movie.
# * **belongs_to_collection:** Gives information on the movie series/franchise the particular film belongs to.
# * **original_language:** The language in which the movie was originally shot in.
# * **budget_musd:** The budget of the movie in million dollars.
# * **revenue_musd:** The total revenue of the movie in million dollars.
# * **production_companies:** Production companies involved with the making of the movie.
# * **production_countries:** Countries where the movie was shot/produced in.
# * **vote_count:** The number of votes by users, as counted by TMDB.
# * **vote_average:** The average rating of the movie.
# * **popularity:** The Popularity Score assigned by TMDB.
# * **runtime:** The runtime of the movie in minutes.
# * **overview:** A brief blurb of the movie.
# * **spoken_languages:** Spoken languages in the film.
# * **poster_path:** The URL of the poster image.
# * **cast:** (Main) Actors appearing in the movie.
# * **cast_size:** number of Actors appearing in the movie.
# * **director:** Director of the movie.
# * **crew_size:** Size of the film crew (incl. director, excl. actors).

# %%
df.genres[1]
# Out:
# 1    Adventure|Fantasy|Family
# 1                 Documentary
# Name: genres, dtype: object

# %%
df.cast[1]
# Out:
# 1    Robin Williams|Jonathan Hyde|Kirsten Dunst|Bra...
# 1    Terry Brunk|David Cash|Carlos Santiago Espada ...
# Name: cast, dtype: object

# %%
df.describe()
# Out:
#              id                   release_date  budget_musd  revenue_musd  \
# count  44691.00                          44657      8854.00       7385.00
# mean  107186.24  1992-04-28 16:30:02.539355520        21.67         68.97
# min        2.00            1874-12-09 00:00:00         0.00          0.00
# 25%    26033.50            1978-08-12 00:00:00         2.00          2.41
# 50%    59110.00            2001-08-16 00:00:00         8.20         16.87
# 75%   154251.00            2010-12-10 00:00:00        25.00         67.64
# max   469172.00            2017-12-27 00:00:00       380.00       2787.97
# std   111806.36                            NaN        34.36        146.61
#
#        vote_count  vote_average  popularity  runtime  cast_size  crew_size
# count    44691.00      42077.00    44691.00 43179.00   44691.00   44691.00
# mean       111.65          6.00        2.96    97.57      12.48      10.31
# min          0.00          0.00        0.00     1.00       0.00       0.00
# 25%          3.00          5.30        0.40    86.00       6.00       2.00
# 50%         10.00          6.10        1.15    95.00      10.00       6.00
# 75%         35.00          6.80        3.77   107.00      15.00      12.00
# max      14075.00         10.00      547.49  1256.00     313.00     435.00
# std        495.32          1.28        6.04    34.65      12.12      15.89

# %%
df.set_index('release_date').resample('y')['id'].count().plot(title="Number of movies")
# Out:
# <Axes: title={'center': 'Number of movies'}, xlabel='release_date'>

# %%
df.budget_musd.hist()
# Out:
# <Axes: >

# %%
df.revenue_musd.hist()
# Out:
# <Axes: >

# %%
df.vote_average.hist()
# Out:
# <Axes: >

# %% [markdown]
# ## The best and the worst movies...

# %%
from IPython.display import HTML
pd.options.display.max_colwidth = 200

# %%
df["profit_musd"] = df.revenue_musd - df.budget_musd
df["ROI"] = df["profit_musd"]/df['budget_musd']

# %%
df_best = df[["poster_path", "title", "budget_musd", "revenue_musd",
              "vote_count", "vote_average", "popularity", "ROI"]].copy()
df_best.head(2)
# Out:
#                                                                                          poster_path  \
# 0  <img src='http://image.tmdb.org/t/p/w185//uXDfjJbdP4ijW5hWSBrPrlKpxab.jpg' style='height:100px;'>
# 1  <img src='http://image.tmdb.org/t/p/w185//vgpXmVaVyUL7GGiDeiK1mKEKzcX.jpg' style='height:100px;'>
#
#        title  budget_musd  revenue_musd  vote_count  vote_average  popularity  \
# 0  Toy Story        30.00        373.55     5415.00          7.70       21.95
# 1    Jumanji        65.00        262.80     2413.00          6.90       17.02
#
#     ROI
# 0 11.45
# 1  3.04

# %%
df_best.head(2)
# Out:
#                                                                                          poster_path  \
# 0  <img src='http://image.tmdb.org/t/p/w185//uXDfjJbdP4ijW5hWSBrPrlKpxab.jpg' style='height:100px;'>
# 1  <img src='http://image.tmdb.org/t/p/w185//vgpXmVaVyUL7GGiDeiK1mKEKzcX.jpg' style='height:100px;'>
#
#        title  budget_musd  revenue_musd  vote_count  vote_average  popularity  \
# 0  Toy Story        30.00        373.55     5415.00          7.70       21.95
# 1    Jumanji        65.00        262.80     2413.00          6.90       17.02
#
#     ROI
# 0 11.45
# 1  3.04

# %%
df_best.columns = ["", "Title", "Budget", "Revenue", "Votes", 
                   "Average Rating", "Popularity", "ROI"]

# %%
df_best.set_index("Title", inplace = True)

# %%
df_best
# Out:
#                                                                                                                                 \
# Title
# Toy Story                    <img src='http://image.tmdb.org/t/p/w185//uXDfjJbdP4ijW5hWSBrPrlKpxab.jpg' style='height:100px;'>
# Jumanji                      <img src='http://image.tmdb.org/t/p/w185//vgpXmVaVyUL7GGiDeiK1mKEKzcX.jpg' style='height:100px;'>
# Grumpier Old Men             <img src='http://image.tmdb.org/t/p/w185//1FSXpj5e8l4KH6nVFO5SPUeraOt.jpg' style='height:100px;'>
# Waiting to Exhale            <img src='http://image.tmdb.org/t/p/w185//4wjGMwPsdlvi025ZqR4rXnFDvBz.jpg' style='height:100px;'>
# Father of the Bride Part II  <img src='http://image.tmdb.org/t/p/w185//lf9RTErt8BSLQy98aSFblElvsCQ.jpg' style='height:100px;'>
# ...                                                                                                                        ...
# Subdue                       <img src='http://image.tmdb.org/t/p/w185//pfC8gZ1BQANxxdadIMpdywbPG9X.jpg' style='height:100px;'>
# Century of Birthing          <img src='http://image.tmdb.org/t/p/w185//xZkmxsNmYXJbKVsTRLLx3pqGHx7.jpg' style='height:100px;'>
# Betrayal                     <img src='http://image.tmdb.org/t/p/w185//eGgakGLQQzUwrCfTxcGu3mXPf8g.jpg' style='height:100px;'>
# Satan Triumphant             <img src='http://image.tmdb.org/t/p/w185//aorBPO7ak8e8iJKT5OcqYxU3jlK.jpg' style='height:100px;'>
# Queerama                     <img src='http://image.tmdb.org/t/p/w185//oxFEU4WOMWdXF3fdtYUJZMzc5ob.jpg' style='height:100px;'>
#
#                              Budget  Revenue   Votes  Average Rating  \
# Title
# Toy Story                     30.00   373.55 5415.00            7.70
# Jumanji                       65.00   262.80 2413.00            6.90
# Grumpier Old Men                NaN      NaN   92.00            6.50
# Waiting to Exhale             16.00    81.45   34.00            6.10
# Father of the Bride Part II     NaN    76.58  173.00            5.70
# ...                             ...      ...     ...             ...
# Subdue                          NaN      NaN    1.00            4.00
# Century of Birthing             NaN      NaN    3.00            9.00
# Betrayal                        NaN      NaN    6.00            3.80
# Satan Triumphant                NaN      NaN    0.00             NaN
# Queerama                        NaN      NaN    0.00             NaN
#
#                              Popularity   ROI
# Title
# Toy Story                         21.95 11.45
# Jumanji                           17.02  3.04
# Grumpier Old Men                  11.71   NaN
# Waiting to Exhale                  3.86  4.09
# Father of the Bride Part II        8.39   NaN
# ...                                 ...   ...
# Subdue                             0.07   NaN
# Century of Birthing                0.18   NaN
# Betrayal                           0.90   NaN
# Satan Triumphant                   0.00   NaN
# Queerama                           0.16   NaN
#
# [44691 rows x 7 columns]

# %%
df_best.iloc[0,0]
# Out:
# "<img src='http://image.tmdb.org/t/p/w185//uXDfjJbdP4ijW5hWSBrPrlKpxab.jpg' style='height:100px;'>"

# %%
subset = df_best.iloc[:5, :2]
subset
# Out:
#                                                                                                                                 \
# Title
# Toy Story                    <img src='http://image.tmdb.org/t/p/w185//uXDfjJbdP4ijW5hWSBrPrlKpxab.jpg' style='height:100px;'>
# Jumanji                      <img src='http://image.tmdb.org/t/p/w185//vgpXmVaVyUL7GGiDeiK1mKEKzcX.jpg' style='height:100px;'>
# Grumpier Old Men             <img src='http://image.tmdb.org/t/p/w185//1FSXpj5e8l4KH6nVFO5SPUeraOt.jpg' style='height:100px;'>
# Waiting to Exhale            <img src='http://image.tmdb.org/t/p/w185//4wjGMwPsdlvi025ZqR4rXnFDvBz.jpg' style='height:100px;'>
# Father of the Bride Part II  <img src='http://image.tmdb.org/t/p/w185//lf9RTErt8BSLQy98aSFblElvsCQ.jpg' style='height:100px;'>
#
#                              Budget
# Title
# Toy Story                     30.00
# Jumanji                       65.00
# Grumpier Old Men                NaN
# Waiting to Exhale             16.00
# Father of the Bride Part II     NaN

# %%
HTML(subset.to_html(escape=False))
# Out:
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th></th>
#       <th>Budget</th>
#     </tr>
#     <tr>
#       <th>Title</th>
#       <th></th>
#       <th></th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>Toy Story</th>
#       <td><img src='http://image.tmdb.org/t/p/w185//uXDfjJbdP4ijW5hWSBrPrlKpxab.jpg' style='height:100px;'></td>
#       <td>30.00</td>
#     </tr>
#     <tr>
#       <th>Jumanji</th>
#       <td><img src='http://image.tmdb.org/t/p/w185//vgpXmVaVyUL7GGiDeiK1mKEKzcX.jpg' style='height:100px;'></td>
#       <td>65.00</td>
#     </tr>
#     <tr>
#       <th>Grumpier Old Men</th>
#       <td><img src='http://image.tmdb.org/t/p/w185//1FSXpj5e8l4KH6nVFO5SPUeraOt.jpg' style='height:100px;'></td>
#       <td>NaN</td>
#     </tr>
#     <tr>
#       <th>Waiting to Exhale</th>
#       <td><img src='http://image.tmdb.org/t/p/w185//4wjGMwPsdlvi025ZqR4rXnFDvBz.jpg' style='height:100px;'></td>
#       <td>16.00</td>
#     </tr>
#     <tr>
#       <th>Father of the Bride Part II</th>
#       <td><img src='http://image.tmdb.org/t/p/w185//lf9RTErt8BSLQy98aSFblElvsCQ.jpg' style='height:100px;'></td>
#       <td>NaN</td>
#     </tr>
#   </tbody>
# </table>

# %%
df_best.sort_values(by = "Average Rating", ascending = False).head(5)
# Out:
#                                                                                                                                                \
# Title
# Portrait of a Young Man in Three Movements                                                                                                NaN
# Brave Revolutionary                         <img src='http://image.tmdb.org/t/p/w185//zAb2YxgYSJTcloGTHAA9ogOVq7M.jpg' style='height:100px;'>
# Other Voices Other Rooms                    <img src='http://image.tmdb.org/t/p/w185//4ifPBA4AjRQWxgVJAwSwWp6nFCa.jpg' style='height:100px;'>
# The Lion of Thebes                          <img src='http://image.tmdb.org/t/p/w185//tdOcmIjI8sx9RZIsVgOlq4kQgJ4.jpg' style='height:100px;'>
# Katt Williams: Priceless: Afterlife         <img src='http://image.tmdb.org/t/p/w185//wKrH5tKdJa3y5jqAQM1eYmkXbHX.jpg' style='height:100px;'>
#
#                                             Budget  Revenue  Votes  \
# Title
# Portrait of a Young Man in Three Movements     NaN      NaN   1.00
# Brave Revolutionary                            NaN      NaN   1.00
# Other Voices Other Rooms                       NaN      NaN   1.00
# The Lion of Thebes                             NaN      NaN   1.00
# Katt Williams: Priceless: Afterlife            NaN      NaN   2.00
#
#                                             Average Rating  Popularity  ROI
# Title
# Portrait of a Young Man in Three Movements           10.00        0.04  NaN
# Brave Revolutionary                                  10.00        0.32  NaN
# Other Voices Other Rooms                             10.00        0.04  NaN
# The Lion of Thebes                                   10.00        1.78  NaN
# Katt Williams: Priceless: Afterlife                  10.00        0.48  NaN

# %%
df_best.sort_values(by = "ROI", ascending = False).head(5)
# Out:
#                                                                                                                             \
# Title
# Less Than Zero           <img src='http://image.tmdb.org/t/p/w185//1GY0ZhAxOR2RgxGnOkeKoKb2mFM.jpg' style='height:100px;'>
# Modern Times             <img src='http://image.tmdb.org/t/p/w185//7uoiKOEjxBBW0AgDGQWrlfGQ90w.jpg' style='height:100px;'>
# Welcome to Dongmakgol     <img src='http://image.tmdb.org/t/p/w185//5iGVw8AdnUJ3xNaZ5iipfsv2e5.jpg' style='height:100px;'>
# Aquí Entre Nos           <img src='http://image.tmdb.org/t/p/w185//oflxxk94TjmjMdotXnajh64iMad.jpg' style='height:100px;'>
# The Karate Kid, Part II  <img src='http://image.tmdb.org/t/p/w185//mSne9mfUcL8QCGxF891LWa7lZNI.jpg' style='height:100px;'>
#
#                          Budget  Revenue  Votes  Average Rating  Popularity  \
# Title
# Less Than Zero             0.00    12.40  77.00            6.10        4.03
# Modern Times               0.00     8.50 881.00            8.10        8.16
# Welcome to Dongmakgol      0.00    33.58  49.00            7.70        4.22
# Aquí Entre Nos             0.00     2.76   3.00            6.00        0.23
# The Karate Kid, Part II    0.00   115.10 457.00            5.90        9.23
#
#                                 ROI
# Title
# Less Than Zero          12396382.00
# Modern Times             8499999.00
# Welcome to Dongmakgol    4197475.62
# Aquí Entre Nos           2755583.00
# The Karate Kid, Part II  1018618.28

# %%
df_best.loc[df_best.Budget >= 5].sort_values(by = "ROI", ascending = False).head(5)
# Out:
#                                                                                                                                \
# Title
# E.T. the Extra-Terrestrial  <img src='http://image.tmdb.org/t/p/w185//cBfkE3HSH1NOyy1ftxlPw2l3ukb.jpg' style='height:100px;'>
# My Big Fat Greek Wedding    <img src='http://image.tmdb.org/t/p/w185//3TB2GJqWS9Ro4JdfV6FP87v3etE.jpg' style='height:100px;'>
# Star Wars                   <img src='http://image.tmdb.org/t/p/w185//6FfCtAuVAW8XJjZ7eWeLibRLWTw.jpg' style='height:100px;'>
# Jaws                        <img src='http://image.tmdb.org/t/p/w185//s2xcqSFfT6F7ZXHxowjxfG0yisT.jpg' style='height:100px;'>
# Crocodile Dundee            <img src='http://image.tmdb.org/t/p/w185//kiwOZXU7ddSrWE3ryOQM8sIg1sZ.jpg' style='height:100px;'>
#
#                             Budget  Revenue   Votes  Average Rating  \
# Title
# E.T. the Extra-Terrestrial   10.50   792.97 3359.00            7.30
# My Big Fat Greek Wedding      5.00   368.74  686.00            6.20
# Star Wars                    11.00   775.40 6778.00            8.10
# Jaws                          7.00   470.65 2628.00            7.50
# Crocodile Dundee              5.00   328.20  512.00            6.30
#
#                             Popularity   ROI
# Title
# E.T. the Extra-Terrestrial       19.36 74.52
# My Big Fat Greek Wedding          6.72 72.75
# Star Wars                        42.15 69.49
# Jaws                             19.73 66.24
# Crocodile Dundee                  7.79 64.64

# %%
df_best.Budget.fillna(0, inplace = True)
df_best.Votes.fillna(0, inplace = True)

# %%
df_best.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 44691 entries, Toy Story to Queerama
# Data columns (total 7 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0                   44467 non-null  object
#  1   Budget          44691 non-null  float64
#  2   Revenue         7385 non-null   float64
#  3   Votes           44691 non-null  float64
#  4   Average Rating  42077 non-null  float64
#  5   Popularity      44691 non-null  float64
#  6   ROI             5371 non-null   float64
# dtypes: float64(6), object(1)
# memory usage: 2.7+ MB

# %%
def best_worst(n, by, ascending = False, min_bud = 0, min_votes = 0):
    
    
    df2 = df_best.loc[(df_best.Budget >= min_bud) & (df_best.Votes >= min_votes), 
                      ["", by]].sort_values(by = by, ascending = ascending).head(n).copy()
    
    return HTML(df2.to_html(escape=False))

# %% [markdown]
# ## The best and the worst movies... (Part 2)

# %% [markdown]
# __Movies Top 5 - Highest Revenue__

# %%
best_worst(n = 5, by = "Revenue")
# Out:
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th></th>
#       <th>Revenue</th>
#     </tr>
#     <tr>
#       <th>Title</th>
#       <th></th>
#       <th></th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>Avatar</th>
#       <td><img src='http://image.tmdb.org/t/p/w185//btnl50ZDJDSCal2NLQIYWw0XxvH.jpg' style='height:100px;'></td>
#       <td>2787.97</td>
#     </tr>
#     <tr>
#       <th>Star Wars: The Force Awakens</th>
#       <td><img src='http://image.tmdb.org/t/p/w185//9rd002JS49RwDW944fF1wjU8iTV.jpg' style='height:100px;'></td>
#       <td>2068.22</td>
#     </tr>
#     <tr>
#       <th>Titanic</th>
#       <td><img src='http://image.tmdb.org/t/p/w185//9xjZS2rlVxm8SFx8kPC3aIGCOYQ.jpg' style='height:100px;'></td>
#       <td>1845.03</td>
#     </tr>
#     <tr>
#       <th>The Avengers</th>
#       <td><img src='http://image.tmdb.org/t/p/w185//RYMX2wcKCBAr24UyPD7xwmjaTn.jpg' style='height:100px;'></td>
#       <td>1519.56</td>
#     </tr>
#     <tr>
#       <th>Jurassic World</th>
#       <td><img src='http://image.tmdb.org/t/p/w185//rhr4y79GpxQF9IsfJItRXVaoGs4.jpg' style='height:100px;'></td>
#       <td>1513.53</td>
#     </tr>
#   </tbody>
# </table>

# %% [markdown]
# __Movies Top 5 - Highest Budget__

# %%
best_worst(5, "Budget")
# Out:
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th></th>
#       <th>Budget</th>
#     </tr>
#     <tr>
#       <th>Title</th>
#       <th></th>
#       <th></th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>Pirates of the Caribbean: On Stranger Tides</th>
#       <td><img src='http://image.tmdb.org/t/p/w185//keGfSvCmYj7CvdRx36OdVrAEibE.jpg' style='height:100px;'></td>
#       <td>380.00</td>
#     </tr>
#     <tr>
#       <th>Pirates of the Caribbean: At World's End</th>
#       <td><img src='http://image.tmdb.org/t/p/w185//oVh3REsCwJwmrTkZ9OkkeKiAE02.jpg' style='height:100px;'></td>
#       <td>300.00</td>
#     </tr>
#     <tr>
#       <th>Avengers: Age of Ultron</th>
#       <td><img src='http://image.tmdb.org/t/p/w185//4ssDuvEDkSArWEdyBl2X5EHvYKU.jpg' style='height:100px;'></td>
#       <td>280.00</td>
#     </tr>
#     <tr>
#       <th>Superman Returns</th>
#       <td><img src='http://image.tmdb.org/t/p/w185//6ZYOpyhFZrAQIe1BuhqVgzfAdGZ.jpg' style='height:100px;'></td>
#       <td>270.00</td>
#     </tr>
#     <tr>
#       <th>Transformers: The Last Knight</th>
#       <td><img src='http://image.tmdb.org/t/p/w185//s5HQf2Gb3lIO2cRcFwNL9sn1o1o.jpg' style='height:100px;'></td>
#       <td>260.00</td>
#     </tr>
#   </tbody>
# </table>

# %% [markdown]
# __Movies Top 5 - Highest ROI__

# %%
best_worst(5, "ROI")
# Out:
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th></th>
#       <th>ROI</th>
#     </tr>
#     <tr>
#       <th>Title</th>
#       <th></th>
#       <th></th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>Less Than Zero</th>
#       <td><img src='http://image.tmdb.org/t/p/w185//1GY0ZhAxOR2RgxGnOkeKoKb2mFM.jpg' style='height:100px;'></td>
#       <td>12396382.00</td>
#     </tr>
#     <tr>
#       <th>Modern Times</th>
#       <td><img src='http://image.tmdb.org/t/p/w185//7uoiKOEjxBBW0AgDGQWrlfGQ90w.jpg' style='height:100px;'></td>
#       <td>8499999.00</td>
#     </tr>
#     <tr>
#       <th>Welcome to Dongmakgol</th>
#       <td><img src='http://image.tmdb.org/t/p/w185//5iGVw8AdnUJ3xNaZ5iipfsv2e5.jpg' style='height:100px;'></td>
#       <td>4197475.62</td>
#     </tr>
#     <tr>
#       <th>Aquí Entre Nos</th>
#       <td><img src='http://image.tmdb.org/t/p/w185//oflxxk94TjmjMdotXnajh64iMad.jpg' style='height:100px;'></td>
#       <td>2755583.00</td>
#     </tr>
#     <tr>
#       <th>The Karate Kid, Part II</th>
#       <td><img src='http://image.tmdb.org/t/p/w185//mSne9mfUcL8QCGxF891LWa7lZNI.jpg' style='height:100px;'></td>
#       <td>1018618.28</td>
#     </tr>
#   </tbody>
# </table>

# %% [markdown]
# __Movies Top 5 - Lowest ROI__

# %%
best_worst(5, "ROI", ascending = True)
# Out:
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th></th>
#       <th>ROI</th>
#     </tr>
#     <tr>
#       <th>Title</th>
#       <th></th>
#       <th></th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>Chasing Liberty</th>
#       <td><img src='http://image.tmdb.org/t/p/w185//7qzvS9QKkiDcz1K8EY9Y6ZXkUeD.jpg' style='height:100px;'></td>
#       <td>-1.00</td>
#     </tr>
#     <tr>
#       <th>The Cookout</th>
#       <td><img src='http://image.tmdb.org/t/p/w185//eUVEPES8KhnXbTG3G74UZfVQRb7.jpg' style='height:100px;'></td>
#       <td>-1.00</td>
#     </tr>
#     <tr>
#       <th>Never Talk to Strangers</th>
#       <td><img src='http://image.tmdb.org/t/p/w185//IHZZLIxqF3ByEZV57RApvfh7uu.jpg' style='height:100px;'></td>
#       <td>-1.00</td>
#     </tr>
#     <tr>
#       <th>To Rob a Thief</th>
#       <td><img src='http://image.tmdb.org/t/p/w185//13mcl6dbOHlaxaJZH5IEYNFipig.jpg' style='height:100px;'></td>
#       <td>-1.00</td>
#     </tr>
#     <tr>
#       <th>Deadfall</th>
#       <td><img src='http://image.tmdb.org/t/p/w185//kgfvIzCG9PYjYfEtcIPuJpGiY9m.jpg' style='height:100px;'></td>
#       <td>-1.00</td>
#     </tr>
#   </tbody>
# </table>

# %% [markdown]
# __Movies Top 5 - Highest ROI__

# %%
best_worst(5, "ROI", min_bud = 50)
# Out:
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th></th>
#       <th>ROI</th>
#     </tr>
#     <tr>
#       <th>Title</th>
#       <th></th>
#       <th></th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>Minions</th>
#       <td><img src='http://image.tmdb.org/t/p/w185//tMaGZ2HR8HAFwkx4YRib0CDVfNT.jpg' style='height:100px;'></td>
#       <td>14.63</td>
#     </tr>
#     <tr>
#       <th>Jurassic Park</th>
#       <td><img src='http://image.tmdb.org/t/p/w185//oU7Oq2kFAAlGqbU4VoAE36g4hoI.jpg' style='height:100px;'></td>
#       <td>13.60</td>
#     </tr>
#     <tr>
#       <th>The Twilight Saga: New Moon</th>
#       <td><img src='http://image.tmdb.org/t/p/w185//j5jM5pq78ObAXX1WhTsb115EkLl.jpg' style='height:100px;'></td>
#       <td>13.20</td>
#     </tr>
#     <tr>
#       <th>Deadpool</th>
#       <td><img src='http://image.tmdb.org/t/p/w185//fSRb7vyIP8rQpL0I47P3qUsEKX3.jpg' style='height:100px;'></td>
#       <td>12.50</td>
#     </tr>
#     <tr>
#       <th>Despicable Me 2</th>
#       <td><img src='http://image.tmdb.org/t/p/w185//xL6t0Fo38DjiiuNLVSj58xJWNJy.jpg' style='height:100px;'></td>
#       <td>11.77</td>
#     </tr>
#   </tbody>
# </table>

# %% [markdown]
# __Movies Top 5 - Lowest ROI__

# %%
best_worst(5, "ROI", ascending = True, min_bud = 100)
# Out:
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th></th>
#       <th>ROI</th>
#     </tr>
#     <tr>
#       <th>Title</th>
#       <th></th>
#       <th></th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>The Adventures of Pluto Nash</th>
#       <td><img src='http://image.tmdb.org/t/p/w185//96vvhLWWDosS1zRrfQ6XEGAzByL.jpg' style='height:100px;'></td>
#       <td>-0.93</td>
#     </tr>
#     <tr>
#       <th>The Alamo</th>
#       <td><img src='http://image.tmdb.org/t/p/w185//aZrWYkxCCwSPKp4VjVvn46uHbIX.jpg' style='height:100px;'></td>
#       <td>-0.82</td>
#     </tr>
#     <tr>
#       <th>Live by Night</th>
#       <td><img src='http://image.tmdb.org/t/p/w185//bkd46T4RplawnDjpHoI8mhzTLks.jpg' style='height:100px;'></td>
#       <td>-0.79</td>
#     </tr>
#     <tr>
#       <th>Mars Needs Moms</th>
#       <td><img src='http://image.tmdb.org/t/p/w185//lOKqLd0ud1wdwaPK5h6bGNZIVLT.jpg' style='height:100px;'></td>
#       <td>-0.74</td>
#     </tr>
#     <tr>
#       <th>The Lone Ranger</th>
#       <td><img src='http://image.tmdb.org/t/p/w185//b2je2ZybNIzAOL1K1WPbbT6zt2M.jpg' style='height:100px;'></td>
#       <td>-0.65</td>
#     </tr>
#   </tbody>
# </table>

# %% [markdown]
# __Movies Top 5 - Most Votes__

# %%
best_worst(5, "Votes")
# Out:
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th></th>
#       <th>Votes</th>
#     </tr>
#     <tr>
#       <th>Title</th>
#       <th></th>
#       <th></th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>Inception</th>
#       <td><img src='http://image.tmdb.org/t/p/w185//9gk7adHYeDvHkCSEqAvQNLV5Uge.jpg' style='height:100px;'></td>
#       <td>14075.00</td>
#     </tr>
#     <tr>
#       <th>The Dark Knight</th>
#       <td><img src='http://image.tmdb.org/t/p/w185//qJ2tW6WMUDux911r6m7haRef0WH.jpg' style='height:100px;'></td>
#       <td>12269.00</td>
#     </tr>
#     <tr>
#       <th>Avatar</th>
#       <td><img src='http://image.tmdb.org/t/p/w185//btnl50ZDJDSCal2NLQIYWw0XxvH.jpg' style='height:100px;'></td>
#       <td>12114.00</td>
#     </tr>
#     <tr>
#       <th>The Avengers</th>
#       <td><img src='http://image.tmdb.org/t/p/w185//RYMX2wcKCBAr24UyPD7xwmjaTn.jpg' style='height:100px;'></td>
#       <td>12000.00</td>
#     </tr>
#     <tr>
#       <th>Deadpool</th>
#       <td><img src='http://image.tmdb.org/t/p/w185//fSRb7vyIP8rQpL0I47P3qUsEKX3.jpg' style='height:100px;'></td>
#       <td>11444.00</td>
#     </tr>
#   </tbody>
# </table>

# %% [markdown]
# __Movies Top 5 - Highest Rating__

# %%
best_worst(5, "Average Rating", min_votes = 50)
# Out:
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th></th>
#       <th>Average Rating</th>
#     </tr>
#     <tr>
#       <th>Title</th>
#       <th></th>
#       <th></th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>Planet Earth II</th>
#       <td><img src='http://image.tmdb.org/t/p/w185//gTvArgUjEUDxYMqJHSwVlrn1Cjk.jpg' style='height:100px;'></td>
#       <td>9.50</td>
#     </tr>
#     <tr>
#       <th>Dilwale Dulhania Le Jayenge</th>
#       <td><img src='http://image.tmdb.org/t/p/w185//2CAL2433ZeIihfX1Hb2139CX0pW.jpg' style='height:100px;'></td>
#       <td>9.10</td>
#     </tr>
#     <tr>
#       <th>Planet Earth</th>
#       <td><img src='http://image.tmdb.org/t/p/w185//koVzjt54bJEVuKTmGC4cExcbE2w.jpg' style='height:100px;'></td>
#       <td>8.80</td>
#     </tr>
#     <tr>
#       <th>Sansho the Bailiff</th>
#       <td><img src='http://image.tmdb.org/t/p/w185//p64ilrhG8DPetzhVk10vuVjAG0t.jpg' style='height:100px;'></td>
#       <td>8.70</td>
#     </tr>
#     <tr>
#       <th>The Jinx: The Life and Deaths of Robert Durst</th>
#       <td><img src='http://image.tmdb.org/t/p/w185//jLqQrtpmB8RLqwuBDGR2OlLdoeC.jpg' style='height:100px;'></td>
#       <td>8.60</td>
#     </tr>
#   </tbody>
# </table>

# %% [markdown]
# __Movies Top 5 - Lowest Rating__

# %%
best_worst(5, "Average Rating", ascending = True, min_votes = 100)
# Out:
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th></th>
#       <th>Average Rating</th>
#     </tr>
#     <tr>
#       <th>Title</th>
#       <th></th>
#       <th></th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>House of the Dead</th>
#       <td><img src='http://image.tmdb.org/t/p/w185//5jBIUM0tqq8QwNbY8w1RZdU6uWz.jpg' style='height:100px;'></td>
#       <td>2.80</td>
#     </tr>
#     <tr>
#       <th>Dragonball Evolution</th>
#       <td><img src='http://image.tmdb.org/t/p/w185//23PcKOqNdhKeMFzORzQGn5eC44N.jpg' style='height:100px;'></td>
#       <td>2.90</td>
#     </tr>
#     <tr>
#       <th>Battlefield Earth</th>
#       <td><img src='http://image.tmdb.org/t/p/w185//wXCRuBHdJ5aTFQdsuGJFXNdo79T.jpg' style='height:100px;'></td>
#       <td>3.00</td>
#     </tr>
#     <tr>
#       <th>Disaster Movie</th>
#       <td><img src='http://image.tmdb.org/t/p/w185//3J8XKUfhJiNzwobUZVtizXYPe8b.jpg' style='height:100px;'></td>
#       <td>3.10</td>
#     </tr>
#     <tr>
#       <th>Alone in the Dark</th>
#       <td><img src='http://image.tmdb.org/t/p/w185//tQZbMfQmsUvfoR2nZyqXLOAKzmk.jpg' style='height:100px;'></td>
#       <td>3.10</td>
#     </tr>
#   </tbody>
# </table>

# %%
best_worst(5, "Average Rating", ascending = True, min_votes = 20, min_bud = 20)
# Out:
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th></th>
#       <th>Average Rating</th>
#     </tr>
#     <tr>
#       <th>Title</th>
#       <th></th>
#       <th></th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>Foodfight!</th>
#       <td><img src='http://image.tmdb.org/t/p/w185//R1zn75Yz4wpdd85byqhP7mT6No.jpg' style='height:100px;'></td>
#       <td>2.30</td>
#     </tr>
#     <tr>
#       <th>Dragonball Evolution</th>
#       <td><img src='http://image.tmdb.org/t/p/w185//23PcKOqNdhKeMFzORzQGn5eC44N.jpg' style='height:100px;'></td>
#       <td>2.90</td>
#     </tr>
#     <tr>
#       <th>Battlefield Earth</th>
#       <td><img src='http://image.tmdb.org/t/p/w185//wXCRuBHdJ5aTFQdsuGJFXNdo79T.jpg' style='height:100px;'></td>
#       <td>3.00</td>
#     </tr>
#     <tr>
#       <th>Disaster Movie</th>
#       <td><img src='http://image.tmdb.org/t/p/w185//3J8XKUfhJiNzwobUZVtizXYPe8b.jpg' style='height:100px;'></td>
#       <td>3.10</td>
#     </tr>
#     <tr>
#       <th>Alone in the Dark</th>
#       <td><img src='http://image.tmdb.org/t/p/w185//tQZbMfQmsUvfoR2nZyqXLOAKzmk.jpg' style='height:100px;'></td>
#       <td>3.10</td>
#     </tr>
#   </tbody>
# </table>

# %% [markdown]
# __Movies Top 5 - Most Popular__

# %%
best_worst(5, "Popularity")
# Out:
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th></th>
#       <th>Popularity</th>
#     </tr>
#     <tr>
#       <th>Title</th>
#       <th></th>
#       <th></th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>Minions</th>
#       <td><img src='http://image.tmdb.org/t/p/w185//tMaGZ2HR8HAFwkx4YRib0CDVfNT.jpg' style='height:100px;'></td>
#       <td>547.49</td>
#     </tr>
#     <tr>
#       <th>Wonder Woman</th>
#       <td><img src='http://image.tmdb.org/t/p/w185//gfJGlDaHuWimErCr5Ql0I8x9QSy.jpg' style='height:100px;'></td>
#       <td>294.34</td>
#     </tr>
#     <tr>
#       <th>Beauty and the Beast</th>
#       <td><img src='http://image.tmdb.org/t/p/w185//tWqifoYuwLETmmasnGHO7xBjEtt.jpg' style='height:100px;'></td>
#       <td>287.25</td>
#     </tr>
#     <tr>
#       <th>Baby Driver</th>
#       <td><img src='http://image.tmdb.org/t/p/w185//rmnQ9jKW72bHu8uKlMjPIb2VLMI.jpg' style='height:100px;'></td>
#       <td>228.03</td>
#     </tr>
#     <tr>
#       <th>Big Hero 6</th>
#       <td><img src='http://image.tmdb.org/t/p/w185//xozrGME58olN1xBhtxmjpOoY0jH.jpg' style='height:100px;'></td>
#       <td>213.85</td>
#     </tr>
#   </tbody>
# </table>

# %% [markdown]
# ## Find your next Movie

# %% [markdown]
# __Search 1: Science Fiction Action Movie with Bruce Willis (high Rating)__

# %%
df.genres[0]
# Out:
# 0    Animation|Comedy|Family
# 0            Action|Thriller
# Name: genres, dtype: object

# %%
mask_genres = df.genres.str.contains("Action") & df.genres.str.contains("Science Fiction")

# %%
df.cast[0]
# Out:
# 0    Tom Hanks|Tim Allen|Don Rickles|Jim Varney|Wallace Shawn|John Ratzenberger|Annie Potts|John Morris|Erik von Detten|Laurie Metcalf|R. Lee Ermey|Sarah Freeman|Penn Jillette
# 0                                                                                                                             Corey Michael Eubanks|Michael Ironside|Don Swayze
# Name: cast, dtype: object

# %%
mask_actor = df.cast.str.contains("Bruce Willis")

# %%
df.loc[mask_actor & mask_genres, ["title", "vote_average"]].sort_values(by = "vote_average", 
                                                                        ascending = False)
# Out:
#                        title  vote_average
# 1448       The Fifth Element          7.30
# 19218                 Looper          6.60
# 1786              Armageddon          6.50
# 14135             Surrogates          5.90
# 20333  G.I. Joe: Retaliation          5.40
# 5274                    Vice          4.10

# %% [markdown]
# __Search 2: Movies with Uma Thurman and directed by Quentin Tarantino (low runtime)__

# %%
df.director
# Out:
# 0           John Lasseter
# 1            Joe Johnston
# 2           Howard Deutch
# 3         Forest Whitaker
# 4           Charles Shyer
#                ...
# 22341    Hamid Nematollah
# 22342            Lav Diaz
# 22343      Mark L. Lester
# 22344    Yakov Protazanov
# 22345       Daisy Asquith
# Name: director, Length: 44691, dtype: object

# %%
mask_director = df.director == "Quentin Tarantino"

# %%
mask_actor = df.cast.str.contains("Uma Thurman")

# %%
df.loc[mask_director & mask_actor, 
               ["title", "poster_path", "runtime"]].sort_values(by = "runtime").set_index("title")
# Out:
#                                                                                                          poster_path  \
# title
# Kill Bill: Vol. 1  <img src='http://image.tmdb.org/t/p/w185//v7TaX8kXMXs5yFFGR41guUDNcnB.jpg' style='height:100px;'>
# Kill Bill: Vol. 2  <img src='http://image.tmdb.org/t/p/w185//2yhg0mZQMhDyvUQ4rG1IZ4oIA8L.jpg' style='height:100px;'>
# Pulp Fiction       <img src='http://image.tmdb.org/t/p/w185//d5iIlFn5s0ImszYzBPb8JPIfbXD.jpg' style='height:100px;'>
#
#                    runtime
# title
# Kill Bill: Vol. 1   111.00
# Kill Bill: Vol. 2   136.00
# Pulp Fiction        154.00

# %% [markdown]
# __Search 3: Most Successful Pixar Studio Movies between 2010 and 2015 (high Revenue)__

# %%
df.production_companies[1]
# Out:
# 1    TriStar Pictures|Teitler Film|Interscope Communications
# 1                                                        NaN
# Name: production_companies, dtype: object

# %%
mask_studio = df.production_companies.str.contains("Pixar").fillna(False)

# %%
df.release_date
# Out:
# 0       1995-10-30
# 1       1995-12-15
# 2       1995-12-22
# 3       1995-12-22
# 4       1995-02-10
#            ...
# 22341          NaT
# 22342   2011-11-17
# 22343   2003-08-01
# 22344   1917-10-21
# 22345   2017-06-09
# Name: release_date, Length: 44691, dtype: datetime64[ns]

# %%
mask_time = df.release_date.between("2010-01-01", "2015-12-31")

# %%
df.loc[mask_studio & mask_time, 
               ["title", "poster_path", "revenue_musd", "release_date"]].sort_values(by = "revenue_musd", ascending = False).set_index("title")
# Out:
#                                                                                                                   poster_path  \
# title
# Toy Story 3                 <img src='http://image.tmdb.org/t/p/w185//amY0NH1ksd9xJ9boXAMmods6U0D.jpg' style='height:100px;'>
# Inside Out                  <img src='http://image.tmdb.org/t/p/w185//lRHE0vzf3oYJrhbsHXjIkF4Tl5A.jpg' style='height:100px;'>
# Monsters University         <img src='http://image.tmdb.org/t/p/w185//tyHHjZEzJutWggujN1KP0a1jfLX.jpg' style='height:100px;'>
# Cars 2                      <img src='http://image.tmdb.org/t/p/w185//okIz1HyxeVOMzYwwHUjH2pHi74I.jpg' style='height:100px;'>
# Brave                       <img src='http://image.tmdb.org/t/p/w185//8l0pzWBrStFtbZiqeu0cGhxGKkT.jpg' style='height:100px;'>
# The Good Dinosaur           <img src='http://image.tmdb.org/t/p/w185//8RSkxOO80btfKjyiC5ZiTaCHIT8.jpg' style='height:100px;'>
# Day & Night                 <img src='http://image.tmdb.org/t/p/w185//eQ1QUZfblOrusXVfbzzCuUaM7ix.jpg' style='height:100px;'>
# The Blue Umbrella           <img src='http://image.tmdb.org/t/p/w185//iSWV7ra8HJ3gYnZFMMrPe8CBbrv.jpg' style='height:100px;'>
# Toy Story of Terror!        <img src='http://image.tmdb.org/t/p/w185//aNDrMDZYmcoMlJa6K3VicYeAgt1.jpg' style='height:100px;'>
# La luna                     <img src='http://image.tmdb.org/t/p/w185//iS6DB1hIRJHQPs9wWXvIzdnp7oD.jpg' style='height:100px;'>
# Hawaiian Vacation           <img src='http://image.tmdb.org/t/p/w185//tByW10AkjWG0DtZwN2E2trT88DD.jpg' style='height:100px;'>
# Small Fry                   <img src='http://image.tmdb.org/t/p/w185//z096FtMoUZxf9kqzSj39YE6psuD.jpg' style='height:100px;'>
# Partysaurus Rex             <img src='http://image.tmdb.org/t/p/w185//ylj9TnXrTgiETysgBoSb8UQwEUc.jpg' style='height:100px;'>
# The Legend of Mor'du        <img src='http://image.tmdb.org/t/p/w185//8FKR6880g0JRiblbTQEijGlq3Qj.jpg' style='height:100px;'>
# Toy Story That Time Forgot  <img src='http://image.tmdb.org/t/p/w185//jqQPN3X3aV5VmpTiEEASt36nlfi.jpg' style='height:100px;'>
# Lava                        <img src='http://image.tmdb.org/t/p/w185//blZSkXNN4CzRBxdxXnz3YpUjnJp.jpg' style='height:100px;'>
# Sanjay's Super Team         <img src='http://image.tmdb.org/t/p/w185//mShcGzOctlq6zs33UdrCdAwZMGq.jpg' style='height:100px;'>
# Air Mater                   <img src='http://image.tmdb.org/t/p/w185//jDwglSvFNBfWJNiyxD41CUcUic1.jpg' style='height:100px;'>
# Riley's First Date?         <img src='http://image.tmdb.org/t/p/w185//pyry5DuBCUiX02OtXRpPsjJ1r0L.jpg' style='height:100px;'>
#
#                             revenue_musd release_date
# title
# Toy Story 3                      1066.97   2010-06-16
# Inside Out                        857.61   2015-06-09
# Monsters University               743.56   2013-06-20
# Cars 2                            559.85   2011-06-11
# Brave                             538.98   2012-06-21
# The Good Dinosaur                 331.93   2015-11-14
# Day & Night                          NaN   2010-06-17
# The Blue Umbrella                    NaN   2013-02-12
# Toy Story of Terror!                 NaN   2013-10-15
# La luna                              NaN   2011-01-01
# Hawaiian Vacation                    NaN   2011-06-16
# Small Fry                            NaN   2011-11-23
# Partysaurus Rex                      NaN   2012-09-14
# The Legend of Mor'du                 NaN   2012-01-01
# Toy Story That Time Forgot           NaN   2014-12-02
# Lava                                 NaN   2015-06-21
# Sanjay's Super Team                  NaN   2015-11-25
# Air Mater                            NaN   2011-08-04
# Riley's First Date?                  NaN   2015-11-03

# %% [markdown]
# __Search 4: Action or Thriller Movie with original language English and minimum Rating of 7.5 (most recent)__

# %%
mask_genre = df.genres.str.contains("Action") | df.genres.str.contains("Thriller")

# %%
mask_lan = df.original_language == "en"

# %%
mask_vote_av = df.vote_average >= 7.5

# %%
mask_vote_co = df.vote_count >= 10

# %%
df.loc[mask_genre & mask_lan & mask_vote_av & mask_vote_co, 
               ["title", "poster_path", "genres", "vote_average", "vote_count", "release_date"]].sort_values(by = "release_date", ascending = False).set_index("title").head(20)
# Out:
#                                                                                                                       poster_path  \
# title
# Descendants 2                   <img src='http://image.tmdb.org/t/p/w185//8BNyZlBk4Hs92z6UrvFDjvx3yMb.jpg' style='height:100px;'>
# Dunkirk                         <img src='http://image.tmdb.org/t/p/w185//ebSnODDg9lbsMIaWg2uAbjn7TO5.jpg' style='height:100px;'>
# The Book of Henry               <img src='http://image.tmdb.org/t/p/w185//suLFg4UjvM5BoDipg2Wu3gZ802T.jpg' style='height:100px;'>
# Guardians of the Galaxy Vol. 2  <img src='http://image.tmdb.org/t/p/w185//y4MBh0EjBlMuOzv9axM4qJlmhzz.jpg' style='height:100px;'>
# Logan                           <img src='http://image.tmdb.org/t/p/w185//fnbjcRDYn6YviCcePDnGdyAkYsB.jpg' style='height:100px;'>
# The Thinning                    <img src='http://image.tmdb.org/t/p/w185//55yQMgLwJDyEom2Kose80JjTlDt.jpg' style='height:100px;'>
# 11.22.63                        <img src='http://image.tmdb.org/t/p/w185//5EJGeeuPy19EGDy8HErpbHba0yq.jpg' style='height:100px;'>
# Star Wars: The Force Awakens    <img src='http://image.tmdb.org/t/p/w185//9rd002JS49RwDW944fF1wjU8iTV.jpg' style='height:100px;'>
# London Spy                       <img src='http://image.tmdb.org/t/p/w185//Ef9ZvB7p0BWJwEup7KE6x96NDw.jpg' style='height:100px;'>
# Spotlight                       <img src='http://image.tmdb.org/t/p/w185//28Vnvn1WI1wJtP1kDqeRCZ1GdYm.jpg' style='height:100px;'>
# Room                            <img src='http://image.tmdb.org/t/p/w185//pCURNjeomWbMSdiP64gj8NVVHTQ.jpg' style='height:100px;'>
# The Fear of 13                  <img src='http://image.tmdb.org/t/p/w185//k5uLNLfmX5aUVm9uiYpAA1uj4BQ.jpg' style='height:100px;'>
# 3 ½ Minutes, 10 Bullets         <img src='http://image.tmdb.org/t/p/w185//nUQDNzBp8IvqkvLYdCYsoQhaDaS.jpg' style='height:100px;'>
# An Inspector Calls              <img src='http://image.tmdb.org/t/p/w185//2e0zkY38Qykc69C4eK7uCMOIHfM.jpg' style='height:100px;'>
# Kung Fury                       <img src='http://image.tmdb.org/t/p/w185//nbWY6797LUxXRSYwamHp8V0X4dA.jpg' style='height:100px;'>
# Kingsman: The Secret Service    <img src='http://image.tmdb.org/t/p/w185//r6q9wZK5a2K51KFj4LWVID6Ja1r.jpg' style='height:100px;'>
# Black Mirror: White Christmas   <img src='http://image.tmdb.org/t/p/w185//he609rnU3tiwBjRklKNa4n2jQSd.jpg' style='height:100px;'>
# The Imitation Game              <img src='http://image.tmdb.org/t/p/w185//ntZGfHt4d73A9fDD4KUN4nbDQlq.jpg' style='height:100px;'>
# Big Hero 6                      <img src='http://image.tmdb.org/t/p/w185//xozrGME58olN1xBhtxmjpOoY0jH.jpg' style='height:100px;'>
# Nightcrawler                    <img src='http://image.tmdb.org/t/p/w185//gYPIRu0jX2CGYdeO422cq3N78ju.jpg' style='height:100px;'>
#
#                                                                                 genres  \
# title
# Descendants 2                            TV Movie|Family|Action|Comedy|Music|Adventure
# Dunkirk                                              Action|Drama|History|Thriller|War
# The Book of Henry                                                 Thriller|Drama|Crime
# Guardians of the Galaxy Vol. 2                 Action|Adventure|Comedy|Science Fiction
# Logan                                                     Action|Drama|Science Fiction
# The Thinning                                                                  Thriller
# 11.22.63                                                        Drama|History|Thriller
# Star Wars: The Force Awakens                  Action|Adventure|Science Fiction|Fantasy
# London Spy                                        Romance|Crime|Drama|Mystery|Thriller
# Spotlight                                                       Drama|Thriller|History
# Room                                                                    Drama|Thriller
# The Fear of 13                                                    Thriller|Documentary
# 3 ½ Minutes, 10 Bullets                                           Thriller|Documentary
# An Inspector Calls                                                Drama|Crime|Thriller
# Kung Fury                                        Action|Comedy|Science Fiction|Fantasy
# Kingsman: The Secret Service                             Crime|Comedy|Action|Adventure
# Black Mirror: White Christmas   Drama|Horror|Mystery|Science Fiction|Thriller|TV Movie
# The Imitation Game                                          History|Drama|Thriller|War
# Big Hero 6                                    Adventure|Family|Animation|Action|Comedy
# Nightcrawler                                                      Crime|Drama|Thriller
#
#                                 vote_average  vote_count release_date
# title
# Descendants 2                           7.50      171.00   2017-07-21
# Dunkirk                                 7.50     2712.00   2017-07-19
# The Book of Henry                       7.60       84.00   2017-06-16
# Guardians of the Galaxy Vol. 2          7.60     4858.00   2017-04-19
# Logan                                   7.60     6310.00   2017-02-28
# The Thinning                            7.60       92.00   2016-10-12
# 11.22.63                                8.00      213.00   2016-02-15
# Star Wars: The Force Awakens            7.50     7993.00   2015-12-15
# London Spy                              8.80       12.00   2015-11-09
# Spotlight                               7.80     2751.00   2015-11-06
# Room                                    8.10     2838.00   2015-10-16
# The Fear of 13                          8.00       45.00   2015-10-15
# 3 ½ Minutes, 10 Bullets                 7.80       30.00   2015-10-02
# An Inspector Calls                      7.60       42.00   2015-09-13
# Kung Fury                               7.60      762.00   2015-05-22
# Kingsman: The Secret Service            7.60     6069.00   2015-01-29
# Black Mirror: White Christmas           8.30      211.00   2014-12-16
# The Imitation Game                      8.00     5895.00   2014-11-14
# Big Hero 6                              7.80     6289.00   2014-10-24
# Nightcrawler                            7.60     3475.00   2014-10-23

# %% [markdown]
# ## What are the most common Words in Movie Titles and Taglines?

# %%
from wordcloud import WordCloud

# %%
title = df.title.dropna()
overview = df.overview.dropna()
tagline = df.tagline.dropna()

# %%
title_corpus = ' '.join(title)
overview_corpus = ' '.join(overview)
tagline_corpus = ' '.join(tagline)

# %%
title_wordcloud = WordCloud(background_color='white', height=2000, width=4000, max_words= 200).generate(title_corpus)

# %%
plt.figure(figsize=(16,8))
plt.imshow(title_wordcloud, interpolation= "bilinear")
plt.axis('off')
plt.show()

# %%
tagline_wordcloud = WordCloud(background_color='white', height=2000, width=4000).generate(tagline_corpus)
plt.figure(figsize=(16,8))
plt.imshow(tagline_wordcloud, interpolation= "bilinear")
plt.axis('off')
plt.show()

# %%
overview_wordcloud = WordCloud(background_color='white', height=2000, width=4000).generate(overview_corpus)
plt.figure(figsize=(16,8))
plt.imshow(overview_wordcloud, interpolation= "bilinear")
plt.axis('off')
plt.show()

# %% [markdown]
# ## Are Franchises more successful?

# %%
df.belongs_to_collection
# Out:
# 0                  Toy Story Collection
# 1                                   NaN
# 2             Grumpy Old Men Collection
# 3                                   NaN
# 4        Father of the Bride Collection
#                       ...
# 22341                               NaN
# 22342                               NaN
# 22343                               NaN
# 22344                               NaN
# 22345                               NaN
# Name: belongs_to_collection, Length: 44691, dtype: object

# %%
df["Franchise"] = df.belongs_to_collection.notna()

# %%
df.Franchise
# Out:
# 0         True
# 1        False
# 2         True
# 3        False
# 4         True
#          ...
# 22341    False
# 22342    False
# 22343    False
# 22344    False
# 22345    False
# Name: Franchise, Length: 44691, dtype: bool

# %%
df.Franchise.value_counts()
# Out:
# Franchise
# False    40228
# True      4463
# Name: count, dtype: int64

# %%
df.columns
# Out:
# Index(['id', 'title', 'tagline', 'release_date', 'genres',
#        'belongs_to_collection', 'original_language', 'budget_musd',
#        'revenue_musd', 'production_companies', 'production_countries',
#        'vote_count', 'vote_average', 'popularity', 'runtime', 'overview',
#        'spoken_languages', 'poster_path', 'cast', 'cast_size', 'crew_size',
#        'director', 'profit_musd', 'ROI', 'Franchise'],
#       dtype='object')

# %%
df.groupby("Franchise").agg({"budget_musd": "mean", "revenue_musd": "mean", "vote_average": "mean",
                            "popularity": "mean", "ROI":"median", "vote_count":"mean"})
# Out:
#            budget_musd  revenue_musd  vote_average  popularity  ROI  \
# Franchise
# False            18.05         44.74          6.01        2.59 0.62
# True             38.32        165.71          5.96        6.25 2.71
#
#            vote_count
# Franchise
# False           78.29
# True           412.39

# %% [markdown]
# ## Most Successful Franchises

# %%
df.belongs_to_collection
# Out:
# 0                  Toy Story Collection
# 1                                   NaN
# 2             Grumpy Old Men Collection
# 3                                   NaN
# 4        Father of the Bride Collection
#                       ...
# 22341                               NaN
# 22342                               NaN
# 22343                               NaN
# 22344                               NaN
# 22345                               NaN
# Name: belongs_to_collection, Length: 44691, dtype: object

# %%
df.belongs_to_collection.value_counts().reset_index().head(5)
# Out:
#            belongs_to_collection  count
# 0                The Bowery Boys     29
# 1                Totò Collection     27
# 2  Zatôichi: The Blind Swordsman     26
# 3          James Bond Collection     26
# 4        The Carry On Collection     25

# %%
df.groupby('belongs_to_collection')['budget_musd'].mean().reset_index()
# Out:
#                      belongs_to_collection  budget_musd
# 0                ... Has Fallen Collection        65.00
# 1                   00 Schneider Filmreihe          NaN
# 2                         08/15 Collection          NaN
# 3                     100 Girls Collection          NaN
# 4     101 Dalmatians (Animated) Collection         4.00
# ...                                    ...          ...
# 1686                     Сказки Чуковского          NaN
# 1687             Чебурашка и крокодил Гена          NaN
# 1688       Что Творят мужчины! (Коллекция)         2.00
# 1689                           男はつらいよ シリーズ          NaN
# 1690                                식객 시리즈          NaN
#
# [1691 rows x 2 columns]

# %%
df.groupby('belongs_to_collection')['vote_average'].mean().reset_index()
# Out:
#                      belongs_to_collection  vote_average
# 0                ... Has Fallen Collection          6.00
# 1                   00 Schneider Filmreihe          6.50
# 2                         08/15 Collection          5.90
# 3                     100 Girls Collection          5.15
# 4     101 Dalmatians (Animated) Collection          6.25
# ...                                    ...           ...
# 1686                     Сказки Чуковского          3.00
# 1687             Чебурашка и крокодил Гена          6.70
# 1688       Что Творят мужчины! (Коллекция)          3.15
# 1689                           男はつらいよ シリーズ          7.00
# 1690                                식객 시리즈          4.95
#
# [1691 rows x 2 columns]

# %%
df.groupby('belongs_to_collection')['popularity'].mean().reset_index()
# Out:
#                      belongs_to_collection  popularity
# 0                ... Has Fallen Collection       13.01
# 1                   00 Schneider Filmreihe        1.93
# 2                         08/15 Collection        0.63
# 3                     100 Girls Collection        3.08
# 4     101 Dalmatians (Animated) Collection       13.06
# ...                                    ...         ...
# 1686                     Сказки Чуковского        0.73
# 1687             Чебурашка и крокодил Гена        0.88
# 1688       Что Творят мужчины! (Коллекция)        1.30
# 1689                           男はつらいよ シリーズ        0.04
# 1690                                식객 시리즈        0.16
#
# [1691 rows x 2 columns]

# %% [markdown]
# ## Most Successful Directors

# %%
df.director
# Out:
# 0           John Lasseter
# 1            Joe Johnston
# 2           Howard Deutch
# 3         Forest Whitaker
# 4           Charles Shyer
#                ...
# 22341    Hamid Nematollah
# 22342            Lav Diaz
# 22343      Mark L. Lester
# 22344    Yakov Protazanov
# 22345       Daisy Asquith
# Name: director, Length: 44691, dtype: object

# %%
df.director.value_counts().head(20)
# Out:
# director
# John Ford             66
# Michael Curtiz        65
# Werner Herzog         54
# Alfred Hitchcock      53
# Georges Méliès        49
# Woody Allen           49
# Jean-Luc Godard       46
# Sidney Lumet          46
# Charlie Chaplin       44
# Raoul Walsh           43
# William A. Wellman    42
# Henry Hathaway        41
# Richard Thorpe        40
# Ingmar Bergman        39
# Martin Scorsese       39
# Fritz Lang            38
# John Huston           38
# George Cukor          38
# Mervyn LeRoy          37
# Robert Altman         37
# Name: count, dtype: int64

# %%
plt.figure(figsize = (12, 8))
df.director.value_counts().head(20).plot(kind='bar', fontsize = 15)
plt.title("Most Active Directors",fontsize = 20)
plt.ylabel("Number of Movies", fontsize = 15)
plt.show()

# %%
df.groupby("director").revenue_musd.sum().nlargest(20)
# Out:
# director
# Steven Spielberg    9256.62
# Peter Jackson       6528.24
# Michael Bay         6437.47
# James Cameron       5900.61
# David Yates         5334.56
# Christopher Nolan   4747.41
# Robert Zemeckis     4138.23
# Tim Burton          4032.92
# Ridley Scott        3917.53
# Chris Columbus      3866.84
# Roland Emmerich     3798.40
# Ron Howard          3714.15
# J.J. Abrams         3579.22
# Gore Verbinski      3575.34
# George Lucas        3341.55
# Sam Raimi           3193.79
# Francis Lawrence    3183.34
# Clint Eastwood      3100.68
# Bill Condon         3017.30
# Joss Whedon         2963.83
# Name: revenue_musd, dtype: float64

# %%
plt.figure(figsize = (12, 8))
df.groupby("director").revenue_musd.sum().nlargest(20).plot(kind='bar', fontsize = 15)
plt.title("Total Revenue",fontsize = 20)
plt.ylabel("Revenue (in MUSD)", fontsize = 15)
plt.show()

# %%
directors = df.groupby("director").agg({"title": "count", "vote_average" :"mean", "vote_count": "sum"})

# %%
directors
# Out:
#                      title  vote_average  vote_count
# director
#  Dale Trevillion\t       2          4.00        4.00
#  Davide Manuli           1          6.90       10.00
#  E.W. Swackhamer         1          5.90        5.00
#  Vitaliy Vorobyov        1          5.50        3.00
#  Yeon Sang-Ho            4          6.60     1039.00
# ...                    ...           ...         ...
# Ярополк Лапшин           1         10.00        1.00
# پیمان معادی              1          6.00        2.00
# 塩谷 直義                    1          7.20       40.00
# 杰森·莫玛                    1          5.80       28.00
# 진모영                      1          6.00        6.00
#
# [17349 rows x 3 columns]

# %%
directors[(directors.vote_count >= 10000) & (directors.title >= 10)].nlargest(20, "vote_average")
# Out:
#                    title  vote_average  vote_count
# director
# Hayao Miyazaki        14          7.70    14700.00
# Christopher Nolan     11          7.62    67344.00
# Quentin Tarantino     10          7.49    45910.00
# Wes Anderson          10          7.37    11743.00
# David Fincher         10          7.35    37588.00
# Martin Scorsese       39          7.22    35541.00
# Peter Jackson         13          7.14    47571.00
# Joel Coen             17          7.02    18139.00
# James Cameron         11          6.93    33736.00
# Stanley Kubrick       16          6.91    18214.00
# James Mangold         10          6.90    16607.00
# Steven Spielberg      33          6.89    62266.00
# Danny Boyle           14          6.87    16504.00
# Guy Ritchie           10          6.80    19626.00
# Robert Zemeckis       19          6.79    37666.00
# Terry Gilliam         14          6.76    10049.00
# Tim Burton            21          6.73    36922.00
# John Lasseter         10          6.72    18337.00
# Ang Lee               14          6.71    11164.00
# Antoine Fuqua         12          6.71    15519.00

# %%
df.genres = df.genres.astype(str)

# %%
df.loc[df.genres.str.contains("Horror")].groupby("director").revenue_musd.sum().nlargest(20)
# Out:
# director
# Paul W.S. Anderson    982.29
# James Wan             861.31
# Wes Craven            834.93
# Francis Lawrence      816.23
# Ridley Scott          689.00
# Marc Forster          531.87
# Steven Spielberg      500.10
# William Friedkin      466.40
# Darren Lynn Bousman   456.34
# M. Night Shyamalan    375.37
# Henry Joost           349.07
# David R. Ellis        348.74
# Adrian Lyne           346.11
# James DeMonaco        316.70
# Stephen Sommers       311.46
# Gore Verbinski        275.91
# Guillermo del Toro    261.63
# John R. Leonetti      255.27
# Fede Alvarez          254.64
# Jordan Peele          252.43
# Name: revenue_musd, dtype: float64

# %% [markdown]
# # Month

# %%
df['Month'] = df['release_date'].dt.month

# %%
df.groupby('Month')['id'].count().plot.bar()
# Out:
# <Axes: xlabel='Month'>

# %%
df[df['release_date'].between('2010-01-01','2020-01-01')].groupby('Month')['popularity'].mean().plot.bar(title="Mean Popularity 2010-2020")
# Out:
# <Axes: title={'center': 'Mean Popularity 2010-2020'}, xlabel='Month'>
